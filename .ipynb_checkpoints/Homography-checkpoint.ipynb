# %%
# %matplotlib tk
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

fig = plt.figure(figsize=(20,30))

img=mpimg.imread('chess.png')
array = []

def onclick(event):
    ix, iy = event.xdata, event.ydata
    print(ix, iy)

cid = fig.canvas.mpl_connect('button_press_event', onclick)

imgplot = plt.imshow(img)
plt.show()
# Out:
# 397.6436670653495 100.15490709435585
# 10.849170771215768 270.52116157953714
# 750.364912462447 296.3915928161758
# 347.16477684751806 620.0874763380202

# %%
# !pip install scikit-image
# Out:
# Collecting scikit-image
#   Using cached scikit_image-0.19.3-cp39-cp39-win_amd64.whl (12.1 MB)
# Requirement already satisfied: packaging>=20.0 in c:\users\gunbo\miniconda3\lib\site-packages (from scikit-image) (21.3)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in c:\users\gunbo\miniconda3\lib\site-packages (from scikit-image) (9.2.0)
# Collecting PyWavelets>=1.1.1
#   Downloading PyWavelets-1.4.1-cp39-cp39-win_amd64.whl (4.2 MB)
#      ---------------------------------------- 4.2/4.2 MB 4.8 MB/s eta 0:00:00
# Collecting scipy>=1.4.1
#   Downloading scipy-1.9.3-cp39-cp39-win_amd64.whl (40.2 MB)
#      ---------------------------------------- 40.2/40.2 MB 3.8 MB/s eta 0:00:00
# Collecting imageio>=2.4.1
#   Downloading imageio-2.22.3-py3-none-any.whl (3.4 MB)
#      ---------------------------------------- 3.4/3.4 MB 5.2 MB/s eta 0:00:00
# Collecting networkx>=2.2
#   Downloading networkx-2.8.8-py3-none-any.whl (2.0 MB)
#      ---------------------------------------- 2.0/2.0 MB 4.8 MB/s eta 0:00:00
# Collecting tifffile>=2019.7.26
#   Downloading tifffile-2022.10.10-py3-none-any.whl (210 kB)
#      -------------------------------------- 210.3/210.3 kB 6.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17.0 in c:\users\gunbo\miniconda3\lib\site-packages (from scikit-image) (1.23.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\gunbo\miniconda3\lib\site-packages (from packaging>=20.0->scikit-image) (3.0.9)
# Installing collected packages: tifffile, scipy, PyWavelets, networkx, imageio, scikit-image
# Successfully installed PyWavelets-1.4.1 imageio-2.22.3 networkx-2.8.8 scikit-image-0.19.3 scipy-1.9.3 tifffile-2022.10.10
# [notice] A new release of pip available: 22.2.2 -> 22.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from skimage.io import imread, imshow
from skimage import transform
import matplotlib.pyplot as plt
import numpy as np

# %%
chess = imread('chess.png')
imshow(chess)

# %%
#source coordinates
src = np.array([391, 100, 
                14, 271,
                347, 624,
                747, 298,]).reshape((4, 2))
#destination coordinates
dst = np.array([100, 100, 
                100, 650,
                650, 650,
                650, 100,]).reshape((4, 2))
#using skimage’s transform module where ‘projective’ is our desired parameter
tform = transform.estimate_transform('projective', src, dst)
tf_img = transform.warp(chess, tform.inverse)
#plotting the transformed image
fig, ax = plt.subplots()
ax.imshow(tf_img)
_ = ax.set_title('projective transformation')
